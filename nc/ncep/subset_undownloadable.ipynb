# %%
import xarray as xr
import pandas as pd

import coordinate_utils as cu

from datetime import datetime
from pathlib import Path
root = Path().cwd()

# %%
ds = xr.open_dataset(root/"nc"/"ncep"/"mslp"/"mslp.2024.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 73, lon: 144, time: 1220, nbnds: 2)
# Coordinates:
#   * lat        (lat) float32 90.0 87.5 85.0 82.5 ... -82.5 -85.0 -87.5 -90.0
#   * lon        (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time       (time) datetime64[ns] 2024-01-01 ... 2024-10-31T18:00:00
# Dimensions without coordinates: nbnds
# Data variables:
#     time_bnds  (time, nbnds) float64 ...
#     mslp       (time, lat, lon) float32 ...
# Attributes:
#     Conventions:    CF-1.0
#     title:          4x Daily NCEP/DOE Reanalysis 2
#     comments:       Data is from \nNCEP/DOE AMIP-II Reanalysis (Reanalysis-2)...
#     platform:       Model
#     source:         NCEP/DOE AMIP-II Reanalysis (Reanalysis-2) Model
#     institution:    National Centers for Environmental Prediction
#     dataset_title:  NCEP-DOE AMIP-II Reanalysis
#     References:     https://www.psl.noaa.gov/data/gridded/data.ncep.reanalysi...
# ...

# %%
subset = ds.sel(lon=slice(cu.convert_lon_0_360(-150),cu.convert_lon_0_360(-90)))
subset = subset.sel(lat=slice(60,20))
subset = subset.sel(time=datetime(year=2024, month=1, day=1, hour=0))
subset.to_netcdf(root/"nc"/"ncep"/"mslp"/"mslp2024.nc")

# %%
ds = xr.open_dataset(root/"nc"/"ncep"/"mslp"/"mslp2024.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 17, lon: 25, nbnds: 2)
# Coordinates:
#   * lat        (lat) float32 60.0 57.5 55.0 52.5 50.0 ... 27.5 25.0 22.5 20.0
#   * lon        (lon) float32 210.0 212.5 215.0 217.5 ... 262.5 265.0 267.5 270.0
#     time       datetime64[ns] ...
# Dimensions without coordinates: nbnds
# Data variables:
#     time_bnds  (nbnds) float64 ...
#     mslp       (lat, lon) float32 ...
# Attributes:
#     Conventions:    CF-1.0
#     title:          4x Daily NCEP/DOE Reanalysis 2
#     comments:       Data is from \nNCEP/DOE AMIP-II Reanalysis (Reanalysis-2)...
#     platform:       Model
#     source:         NCEP/DOE AMIP-II Reanalysis (Reanalysis-2) Model
#     institution:    National Centers for Environmental Prediction
#     dataset_title:  NCEP-DOE AMIP-II Reanalysis
#     References:     https://www.psl.noaa.gov/data/gridded/data.ncep.reanalysi...
#     source_url:     http://www.cpc.ncep.noaa.gov/products/wesley/reanalysis2/
# ...

# %%
import pandas as pd

hours = [1954776, 1954782]
reference_date = pd.Timestamp('1800-01-01')
actual_dates = reference_date + pd.Timedelta(hours=hours[1])

print(actual_dates)
# Out:
# 2023-01-01 06:00:00

# %%
ds_o = xr.open_dataset(root/"nc"/"ncep"/"mslp"/"mslp2022.nc")

# %%
ds_o
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1460, lon: 25, lat: 17)
# Coordinates:
#   * time     (time) datetime64[ns] 2022-01-01 ... 2022-12-31T18:00:00
#   * lon      (lon) float32 210.0 212.5 215.0 217.5 ... 262.5 265.0 267.5 270.0
#   * lat      (lat) float32 60.0 57.5 55.0 52.5 50.0 ... 30.0 27.5 25.0 22.5 20.0
# Data variables:
#     mslp     (time, lat, lon) float32 ...
# Attributes:
#     CDI:            Climate Data Interface version 1.9.10 (https://mpimet.mpg...
#     source:         NCEP/DOE AMIP-II Reanalysis (Reanalysis-2) Model
#     institution:    National Centers for Environmental Prediction
#     Conventions:    CF-1.0
#     title:          4x Daily NCEP/DOE Reanalysis 2
#     comments:       Data is from \nNCEP/DOE AMIP-II Reanalysis (Reanalysis-2)...
#     platform:       Model
#     dataset_title:  NCEP-DOE AMIP-II Reanalysis
#     References:     https://www.psl.noaa.gov/data/gridded/data.ncep.reanalysi...
# ...
